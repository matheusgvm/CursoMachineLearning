# %%
import tensorflow as tf

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
import pathlib
data_dir = tf.keras.utils.get_file(origin='https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
                                    fname='flower_photos', untar=True)
data_dir = pathlib.Path(data_dir)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 2s 0us/step

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 3670

# %%
CLASS_NAMES = np.array([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"])
CLASS_NAMES
# Out:
# array(['daisy', 'roses', 'sunflowers', 'dandelion', 'tulips'],
#       dtype='<U10')

# %%
roses = list(data_dir.glob('roses/*'))
for image_path in roses[:5]:
  display.display(Image.open(str(image_path)))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7FCDC43AC9B0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7FCDC4365F60>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7FCDC43AC9B0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x297 at 0x7FCDC4365F98>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=188x240 at 0x7FCDC435E198>
